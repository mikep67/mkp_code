# %% [markdown]
# # MT Cars dataset - from GitHUB

# %%
# Load data from 'https://coded2.herokuapp.com/datavizpandas/london2018.csv'
# and print it
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the above url using pandas read_csv
# Refer: pandas import csv from url
# http://pythonfiddle.com/pandas-import-csv-from-url/
import io
import requests

url = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
s = requests.get(url).content
ds = pd.read_csv(io.StringIO(s.decode('utf-8')))
#print(ds.describe())
#print(ds)

mtcars = ds

# print(weather.iloc[0:10,0:10])
# print(mtcars.head(10))

# print(mtcars)

mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ## Let's try on a bigger recordset
#
# **let's try Canadian travel data from Statistics Canada**

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv
datafile = pd.read_csv("c:\Users\micha\Documents\Datasets\24100045-eng\24100045.csv", sep = ",")
# Out:
#   File "<ipython-input-5-29f88f1bdae4>", line 12
#     datafile = pd.read_csv("c:\Users\micha\Documents\Datasets\24100045-eng\24100045.csv", sep = ",")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 2: Saved CSV in Excel

datfile = pd.read_csv( "C:\Users\micha\Documents\Datasets\CanadaTravel.csv", sep = ",")
# Out:
#   File "<ipython-input-8-fd302aaa8c38>", line 13
#     datfile = pd.read_csv( "C:\Users\micha\Documents\Datasets\CanadaTravel.csv", sep = ",")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 2: Saved CSV in Excel

datfile = pd.read_csv("C:\Users\micha\Documents\Datasets\CanadaTravel.csv")
# Out:
#   File "<ipython-input-9-e3b52fc0ab02>", line 13
#     datfile = pd.read_csv("C:\Users\micha\Documents\Datasets\CanadaTravel.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 2: Saved CSV in Excel

datfile = pd.read_csv("C:\Users\micha\Documents\Datasets\CanadaTravel.csv")
# Out:
#   File "<ipython-input-10-521e570c5012>", line 13
#     datfile = pd.read_csv("C:\Users\micha\Documents\Datasets\CanadaTravel.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 3: Saved CSV as Excel

datfile = pd.read_excel("C:\Users\micha\Documents\Datasets\CanadaTravel.xlsx")
# Out:
#   File "<ipython-input-11-7dab0e88ffe3>", line 13
#     datfile = pd.read_excel("C:\Users\micha\Documents\Datasets\CanadaTravel.xlsx")
#                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 4: Saved CSV in UTF-08

datfile = pd.read_csv( "C:\Users\micha\Documents\Datasets\CanadaTravel.csv", sep = ",")
# Out:
#   File "<ipython-input-12-13f106a251e4>", line 13
#     datfile = pd.read_csv( "C:\Users\micha\Documents\Datasets\CanadaTravel.csv", sep = ",")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 5: Redownloaded

datfile = pd.read_csv( "C:\Users\micha\Documents\Datasets\24100045.csv", sep = ",")
# Out:
#   File "<ipython-input-13-d546bc90ad3b>", line 13
#     datfile = pd.read_csv( "C:\Users\micha\Documents\Datasets\24100045.csv", sep = ",")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 6: Try another data source

datfile = pd.read_excel( "C:\Users\micha\Documents\Datasets\6291006.xls")
# Out:
#   File "<ipython-input-14-0491fe1b0b72>", line 13
#     datfile = pd.read_excel( "C:\Users\micha\Documents\Datasets\6291006.xls")
#                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "6291006.xls")

print(datfile.head(100))
# Out:
#    Quarter and Year  \
# 0        1984-11-01
# 1        1985-02-01
# 2        1985-05-01
# 3        1985-08-01
# 4        1985-11-01
# ..              ...
# 95       2008-08-01
# 96       2008-11-01
# 97       2009-02-01
# 98       2009-05-01
# 99       2009-08-01
#
#     Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;  \
# 0                                          410.719753
# 1                                          404.842338
# 2                                          394.461506
# 3                                          413.675791
# 4                                          433.581180
# ..                                                ...
# 95                                         347.432997
# 96                                         356.120752
# 97                                         358.092723
# 98                                         338.130694
# 99                                         349.610591
#
# ...

# %% [markdown]
# ## Step required to clean data before processing
#
# ***The data contains descriptiions of data - needs rows removed
# ***Remember - Excel files contain MULTIPLE worksheets.
# ***The Index worksheets and extra data was deleted

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "6291006.xls")

print(datfile.head(100))
# Out:
#    Quarter and Year  \
# 0        1984-11-01
# 1        1985-02-01
# 2        1985-05-01
# 3        1985-08-01
# 4        1985-11-01
# ..              ...
# 95       2008-08-01
# 96       2008-11-01
# 97       2009-02-01
# 98       2009-05-01
# 99       2009-08-01
#
#     Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;  \
# 0                                          410.719753
# 1                                          404.842338
# 2                                          394.461506
# 3                                          413.675791
# 4                                          433.581180
# ..                                                ...
# 95                                         347.432997
# 96                                         356.120752
# 97                                         358.092723
# 98                                         338.130694
# 99                                         349.610591
#
# ...

# %%
# Now - let's check the stats on the dataframe
datfile.describe
# Out:
# <bound method NDFrame.describe of     Unnamed: 0  \
# 0   1984-11-01
# 1   1985-02-01
# 2   1985-05-01
# 3   1985-08-01
# 4   1985-11-01
# ..         ...
# 136 2018-11-01
# 137 2019-02-01
# 138 2019-05-01
# 139 2019-08-01
# 140 2019-11-01
#
#      Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;  \
# 0                                           410.719753
# 1                                           404.842338
# 2                                           394.461506
# 3                                           413.675791
# 4                                           433.581180
# ..                                                 ...
# 136                                         333.012035
# 137                                         346.192988
# 138                                         334.392308
# 139                                         319.087256
# 140                                         319.122861
#
# ...

# %% [markdown]
# ## Describe will fail - 251 columns is too wide
#
# ***Need to try some mapping

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "6291006.xls")
datfile.plot(y = "Quarter and Year", X = "Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-ec951252dc5b> in <module>
#      16 # (in the same directory that your python process is based)
#      17 datfile = pd.read_excel( "6291006.xls")
# ---> 18 datfile.plot(y = "Quarter and Year", X = "Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;")
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
# ...

# %%
# This was expected - what is a valid column name?
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "6291006.xls")
datfile.plot(y = "Quarter and Year", X = "A")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quarter and Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-b3feeb699188> in <module>
# ...

# %%
# This was expected - what is a valid column name?
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "6291006.xls")
datfile.plot(y = "Q", X = "A")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-85e6fca9ecd0> in <module>
#      17 # (in the same directory that your python process is based)
#      18 datfile = pd.read_excel( "6291006.xls")
# ---> 19 datfile.plot(y = "Q", X = "A")
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ...

# %% [markdown]
# ### MATLABLib is not up to the task!
# *** Rule: Don't munge for more than an hour.

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "6291006.xls")
#datfile.plot(y = "Quarter and Year", X = "Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;")
# use seaborn pairplot function to plot relationship between variables
sns.pairplot (datfile,hue="Quarter")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-6f75368fb134> in <module>
#      18 #datfile.plot(y = "Quarter and Year", X = "Agriculture, Forestry and Fishing ;  Employed total ;  Persons ;")
#      19 # use seaborn pairplot function to plot relationship between variables
# ---> 20 sns.pairplot (datfile,hue="Quarter")
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# ...

# %% [markdown]
# *** This is in an infinite looop!!! Or not. 3 - 4 hours .. Maybe later but I have a deadline
# ### Kernel died!!!
