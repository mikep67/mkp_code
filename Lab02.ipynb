# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Python - Lab 2
#
# ## Learning objectives
#
# This lab demonstrates examples of:
#
# 1. Using `numpy` and `matplotlib` modules
# 2. Plotting line, bar, and histogram charts using `matplotlib`
# 3. Simple customisations when creating visualisations
#
# ## Instructions
#
# 1. Replace ??? with the appropriate code
# 2. Press Shift + Enter to execute cell

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
Print(x)
# Create a figure using plt.figure
fig = ???
# Plot the sine wave of x
plt.plot(x, ???, '-')
# Plot the cosine wave of x
???

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Create a figure using plt.figure
fig = plt.figure

# Plot the sine wave of x
plt.plot(x, 10, 100)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Create a figure using plt.figure
fig = plt.figure

# define the sine wave of x
# From Pyionics

# Get x values of the sine wave
time = np.arange(0, 10, 0.1);

# Amplitude of the sine wave is sine of a variable like time
amplitude = np.sin(time)

# Plot a sine wave using time and amplitude obtained for the sine wave
# plt from the lab notes
plt.plot(time, amplitude)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Create a figure using plt.figure
fig = plt.figure

# define the sine wave of x
# From Pyionics

# Get x values of the sine wave
time = np.arange(0, 10, 0.1);

# Amplitude of the sine wave is sine of a variable like time
amplitude = np.sin(time)

# Plot a sine wave using time and amplitude obtained for the sine wave
plot.plot(time, amplitude)

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Create a figure using plt.figure
fig = plt.figure

# define the sine wave of x
# From Pythontics
# https://pythontic.com/visualization/charts/sinewave


# Get x values of the sine wave
time = np.arange(0, 10, 0.1);

# Amplitude of the sine wave is sine of a variable like time
amplitude = np.sin(time)

# Plot a sine wave using time and amplitude obtained for the sine wave
# plt from the lab notes
plt.plot(time, amplitude)

# Give a title for the sine wave plot
plt.title('Sine wave')

# Give x axis label for the sine wave plot
plt.xlabel('Time')

# Give y axis label for the sine wave plot
plt.ylabel('Amplitude = sin(time)')

# Add a grid for content 
plt.grid(True, which='both')

# Define the color if you want!
plt.axhline(y=0, color='k')
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Create a figure using plt.figure
fig = plt.figure

# define the sine wave of x
# From Pythontics
# https://pythontic.com/visualization/charts/sinewave

# Get x values of the sine wave
stime = np.arange(0, 10, 0.1);

# Amplitude of the sine wave is sine of a variable like time
samplitude = np.sin(time)

# Plot a sine wave using time and amplitude obtained for the sine wave
# plt from the lab notes
plt.plot(stime, samplitude)

# Get x values of the cosine wave
ctime = np.arange(0, 20, 0.2);

# Amplitude of the cosine wave is cosine of a variable like time
camplitude  = np.cos(time)
 
# Plot a cosine wave using time and amplitude obtained for the cosine wave
plt.plot(ctime,camplitude)

# Give a title for the sine wave plot
plt.title('Sine and Cosine Wave')

# Give x axis label for the sine wave plot
plt.xlabel('Time')

# Give y axis label for the sine wave plot
plt.ylabel('Amplitude')

# Add a grid for content 
plt.grid(True, which='both')

# Define the color if you want!
plt.axhline(y=0, color='k')
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Practice the use of matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Create a data set 
x = np.linspace(0, 10, 100)
# Print the data
print(x)
# Create a figure using plt.figure
fig = plt.figure

# define the sine wave of x
# From Pythontics
# https://pythontic.com/visualization/charts/sinewave

# Get x values of the sine wave
stime = np.arange(0, 10, 0.1);

# Amplitude of the sine wave is sine of a variable like time
samplitude = np.sin(time)

# Plot a sine wave using time and amplitude obtained for the sine wave
# plt from the lab notes
plt.plot(stime, samplitude)

# Get x values of the cosine wave
ctime = np.arange(0, 10, 0.1);

# Amplitude of the cosine wave is cosine of a variable like time
camplitude  = np.cos(time)
 
# Plot a cosine wave using time and amplitude obtained for the cosine wave
plt.plot(ctime,camplitude)

# Give a title for the sine wave plot
plt.title('Sine and Cosine Wave')

# Give x axis label for the sine wave plot
plt.xlabel('Time')

# Give y axis label for the sine wave plot
plt.ylabel('Amplitude')

# Add a grid for content 
plt.grid(True, which='both')

# Define the color if you want!
plt.axhline(y=0, color='k')
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Create two arrays of 5 arbitrary numbers 
???
# Plot two bar charts using plt.bar and the arrays you've created above
# Label them "Example one" and "example two"
plt.bar(???, label="Example one")
plt.bar(???, label="Example two", color='g')
plt.legend()
# Label x axis "Bar number"
plt.xlabel(???)
# Label y axis "Bar height"
plt.ylabel(???)
# Set title "Bar Graph"
???("Bar Graph")
# Show the chart
plt.show()

# %%
# Create two arrays of 5 arbitrary numbers 
import array as arr
a = arr.array("i", [5,2,7,8,2])
print("First element:", a[0])
print("Second element:", a[1])
# Out:
# First element: 5
# Second element: 2

# %%
# Create two arrays of 5 arbitrary numbers 
import array as arr
# Array has 2 arguments str is type, list contains items
# Refer:
# https://www.programiz.com/python-programming/array

# a = value, b = count
av = arr.array("i", [1,3,5,7,9])
af = arr.array("i", [5,2,2,8,2])

# a = value, b = count
bv = arr.array("i", [2,4,6,8,10])
bf = arr.array("i", [8,6,2,5,6])

# Define the Chart
# BChart = plt.figure

# Plot two bar charts using plt.bar and the arrays you've created above
# Label them "Example one" and "example two"
plt.bar(av,af, label="Example one")
plt.bar(bv,bf, label="Example two", color='g')

# Show the chart
plt.show()

# %%
# Create two arrays of 5 arbitrary numbers 
???
# Plot two bar charts using plt.bar and the arrays you've created above
# Label them "Example one" and "example two"
plt.bar(???, label="Example one")
plt.bar(???, label="Example two", color='g')
plt.legend()
# Label x axis "Bar number"
plt.xlabel(???)
# Label y axis "Bar height"
plt.ylabel(???)
# Set title "Bar Graph"
???("Bar Graph")
# Show the chart
plt.show()
# Out:
#   File "<ipython-input-37-eb7bac9d3bc7>", line 5
#     plt.bar(???, label="Example one")
#             ^
# SyntaxError: invalid syntax

# %%
# Create two arrays of 5 arbitrary numbers 
import array as arr
# Array has 2 arguments str is type, list contains items
# Refer:
# https://www.programiz.com/python-programming/array

# a = value, b = count
av = arr.array("i", [1,3,5,7,9])
af = arr.array("i", [5,2,2,8,2])

# a = value, b = count
bv = arr.array("i", [2,4,6,8,10])
bf = arr.array("i", [8,6,2,5,6])

# Plot two bar charts using plt.bar and the arrays you've created above
# Label them "Example one" and "example two"
plt.bar(av,af,label="Example one")
plt.bar(bv,bf,label="Example two", color='g')

#Show label in legend
plt.legend()

# Label x axis "Bar number"
plt.xlabel("Sample Name")
# Label y axis "Bar height"
plt.ylabel("Occurance")

# Show the chart
plt.show()

# %%
# Histogram Code 
# Create an array of a random normal distribution
??? = np.random.laplace(loc=15, scale=3, size=500)
# Create a histrogram using plt hist()
n, bins, patches = plt.hist(x=???, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
# Set grid for x and y
# set transperancy of the grid using alpha=0.5
plt.grid(axis='???, ???)
plt.grid(axis=???, ???)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My First Histogram Ever')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 80.0)

# %%
# Histogram Code 

# import numpy and pyplot
import numpy as np
import matplotlib.pyplot as plt


# Create an array of a random normal distribution
# Randon normalised values as rv
rv= np.random.laplace(loc=15, scale=3, size=500)

# Create a histrogram using plt hist()
n, bins, patches = plt.hist(x=rv, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
# Set grid for x and y
# set transperancy of the grid using alpha=0.5
plt.grid(axis='???, ???)
plt.grid(axis=???, ???)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My First Histogram Ever')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
#   File "<ipython-input-48-e29df6123f7f>", line 17
#     plt.grid(axis='???, ???)
#                             ^
# SyntaxError: EOL while scanning string literal

# %%
# Histogram Code 

# import numpy and pyplot
import numpy as np
import matplotlib.pyplot as plt


# Create an array of a random normal distribution
# Randon normalised values as rv
rv= np.random.laplace(loc=15, scale=3, size=500)

# Create a histrogram using plt hist()
n, bins, patches = plt.hist(x=???, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
# Set grid for x and y
# set transperancy of the grid using alpha=0.5
plt.grid(axis='???, ???)
plt.grid(axis=???, ???)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My First Histogram Ever')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
#   File "<ipython-input-47-09eb83577418>", line 13
#     n, bins, patches = plt.hist(x=???, bins='auto', color='#0504aa',
#                                   ^
# SyntaxError: invalid syntax

# %%
# Histogram Code 

# import numpy and pyplot
import numpy as np
import matplotlib.pyplot as plt


# Create an array of a random normal distribution
# Randon normalised values as rv
rv= np.random.laplace(loc=15, scale=3, size=500)

# Create a histrogram using plt hist()
n, bins, patches = plt.hist(x=rv, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)

# %%
# Histogram Code 

# import numpy and pyplot
import numpy as np
import matplotlib.pyplot as plt


# Create an array of a random normal distribution
# Randon normalised values as rv
rv= np.random.laplace(loc=15, scale=3, size=500)

# Create a histrogram using plt hist()
# Changed to clor purple
n, bins, patches = plt.hist(x=rv, bins='auto', color='#c203fc', alpha=0.8, rwidth=0.85)


# Set grid for x and y
# set transperancy of the grid using alpha=0.5
plt.grid(axis= "x", alpha=0.5)
plt.grid(axis="y", alpha=0.5)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My First Histogram Ever')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 90.0)

# %%
# Bonus: Create a scatter plot

# %%
# Bonus: Create a scatter plot
# Refer example
# https://pythonspot.com/matplotlib-scatterplot/

import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Bonus: Create a scatter plot
# Refer example
# https://pythonspot.com/matplotlib-scatterplot/

import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
colors = (10,50,40)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4284             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4285                 colors = mcolors.to_rgba_array(c)
#    4286                 n_elem = colors.shape[0]
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# ...

# %%
# Bonus: Create a scatter plot
# Refer example
# https://pythonspot.com/matplotlib-scatterplot/

import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
colors = (194, 3, 252)
area = np.pi*3

# Plot
# Define colors
offsets = np.random.rand(20,2)
facecolors = [cm.jet(x) for x in np.random.rand(20)]
black = (0,0,0,1)

plt.scatter(x, y, s=area, c=facecolors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b984e20d2037> in <module>
#      16 # Define colors
#      17 offsets = np.random.rand(20,2)
# ---> 18 facecolors = [cm.jet(x) for x in np.random.rand(20)]
#      19 black = (0,0,0,1)
#      20
#
# <ipython-input-59-b984e20d2037> in <listcomp>(.0)
#      16 # Define colors
#      17 offsets = np.random.rand(20,2)
# ---> 18 facecolors = [cm.jet(x) for x in np.random.rand(20)]
#      19 black = (0,0,0,1)
#      20
#
# NameError: name 'cm' is not defined

# %%
# Bonus: Create a scatter plot
# Refer example
# https://pythonspot.com/matplotlib-scatterplot/

import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
#colors = (0,0,0,1)
colors = '#1f77b4', '#ff7f0e', '#2ca02c'
area = np.pi*3

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4290                     valid_shape = False
# -> 4291                     raise ValueError
#    4292             except ValueError:
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-71b8a9c1bf9f> in <module>
#      14 area = np.pi*3
#      15
# ---> 16 plt.scatter(x, y, s=area, c=colors, alpha=0.5)
#      17 plt.title('Scatter plot pythonspot.com')
#      18 plt.xlabel('x')
#
# ...

# %% [markdown]
# ### Adding colors to scatterplot requires many more arguements regarding plot area
