# %%
# %matplotlib inline

import os
import sys
import json

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
from IPython.display import display
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Add our local functions to the path
sys.path.append(os.path.join(os.pardir, 'src'))
from models import evaluation
from data.load_data import (get_country_filepaths, 
                            split_features_labels_weights, 
                            load_data)
from features.process_features import get_vif, standardize
from features.process_features import MWI_BASIC_FEATURES

ALGORITHM_NAME = 'dt'
COUNTRY = 'mwi'
TRAIN_PATH, TEST_PATH, QUESTIONS_PATH = get_country_filepaths(COUNTRY)

# load text of survey questions for reference
with open(QUESTIONS_PATH, 'r') as fp:
    questions = json.load(fp)

# %%
# Definition of Main Variables to Predict Poverty from the Household Survey

MWI_BASIC_FEATURES = [
    'der_nchild10under', 
    'der_nmalesover10', 
    'der_nfemalesover10',
    'der_nliterate', 
    'der_nemployedpastyear',
    'hld_electricity__Yes',
    'hld_toilet__None',
    'cons_0504__Yes',
    'cons_0508__Yes'
]

# %%
# Standardise Data
def standardize(df, numeric_only=True):
    if numeric_only is True:
    # find non-boolean columns
        cols = df.loc[:,df.dtypes != 'uint8'].columns
    else:
        cols = df.columns
    for field in cols:
        mean, std = df[field].mean(), df[field].std()
        # account for constant columns
        if np.all(df[field]-mean != 0):
            df.loc[:,field] = (df[field]-mean)/std
    
    return df

# %%
def drop_duplicate_columns(df, ignore=[], inplace=False):
    if not inplace:
        df = df.copy()

    # pairwise correlations
    corr = df.corr()
    corr[corr.columns] = np.triu(corr, k=1)
    corr = corr.stack()

    # for any perfectly correlated variables, drop one of them
    for ix, r in corr[(corr == 1)].to_frame().iterrows():
        first, second = ix

        if second in df.columns and second not in ignore:
            df.drop(second, inplace=True, axis=1)

    if not inplace:
        return df

# %%
# Split the data for analysis
def split_features_labels_weights(df,
                                  weights=['wta_pop', 'wta_hh'],
                                  weights_col=['wta_pop'],
                                  label_col=['poor']):

    '''Split data into features, labels, and weights dataframes'''
    data = df
    return (data.drop(weights + label_col, axis=1),
            data[label_col],
            data[weights_col])

# %%
# Load the processed Mwai household:
mwi_hhold = pd.read_csv("/home/mike/Documents/mkp_code/Institute of Data Course/Project 3/data/csv_data/MWI_2010_household.csv")
#(r"C:\Users\micha\Documents\GitHub\mkp_code\Institute of Data Course\Project 3\data\csv_data\MWI_2010_household.csv")

# %%
# Split Malawi data 
mwi_train, mwi_test = train_test_split(mwi_hhold, 
                                       test_size=0.25,
                                       random_state=1443,
                                       stratify=mwi_hhold.poor)

# %%
# load training data
X_train, y_train, w_train = split_features_labels_weights(mwi_train)

# %%
# summarize loaded data
print('Data has {:,} rows and {:,} columns' \
        .format(*X_train.shape))

print('Percent poor: {:0.1%} \tPercent non-poor: {:0.1%}' \
        .format(*y_train.poor.value_counts(normalize=True, ascending=True)))

# print first 5 rows of data
X_train.head()
# Out:
# Data has 9,183 rows and 485 columns
# Percent poor: 45.1% 	Percent non-poor: 54.9%
#                 hid  der_hhsize  hld_rooms  hld_nbcellpho  hld_selfscale  \
# 7927   304044580160           5          3            0.0            1.0
# 4210   205205820123           3          2            1.0            3.0
# 457    102016880095           6          5            0.0            2.0
# 11951  315356330210           3          3            3.0            3.0
# 11428  313061660067           2          1            0.0            2.0
#
#        der_nchild10under  der_nmalesover10  der_nfemalesover10  der_nliterate  \
# 7927                   3                 1                   1              2
# 4210                   1                 1                   1              2
# 457                    3                 1                   2              2
# 11951                  1                 1                   1              3
# 11428                  0                 1                   1              2
#
#        der_nemployedpastyear  ...  com_medicines__Yes  com_clinic__Yes  \
# 7927                       0  ...                   0                0
# 4210                       1  ...                   1                0
# 457                        0  ...                   0                0
# 11951                      1  ...                   1                1
# 11428                      0  ...                   1                0
#
#        com_distclinic__11 to 15 kilometers  \
# 7927                                     0
# 4210                                     0
# 457                                      0
# 11951                                    0
# 11428                                    0
#
#        com_distclinic__16 to 20 kilometers  \
# 7927                                     0
# 4210                                     0
# 457                                      0
# 11951                                    0
# 11428                                    1
#
#        com_distclinic__21 to 25 kilometers  \
# 7927                                     0
# 4210                                     0
# 457                                      0
# 11951                                    0
# 11428                                    0
#
#        com_distclinic__26 to 30 kilometers  \
# 7927                                     0
# 4210                                     0
# 457                                      0
# 11951                                    0
# 11428                                    0
#
#        com_distclinic__6 to 10 kilometers  \
# 7927                                    0
# 4210                                    0
# 457                                     0
# 11951                                   0
# 11428                                   0
#
#        com_distclinic__Above 30 kilometers  com_distclinic__nan  com_bank__Yes
# 7927                                     0                    0              0
# 4210                                     0                    0              0
# 457                                      0                    0              0
# 11951                                    0                    1              1
# 11428                                    0                    0              0
#
# [5 rows x 485 columns]

# %%
selected_columns = MWI_BASIC_FEATURES
print("X shape with selected columns:", X_train[selected_columns].shape)
# Out:
# X shape with selected columns: (9183, 9)

# %%
# Create DataFrame of feature importances
def get_feat_imp_df(feat_imps, index=None, sort=True):
    feat_imps = pd.DataFrame(feat_imps, columns=['importance'])
    if index is not None:
        feat_imps.index = index
    if sort:
        feat_imps = feat_imps.sort_values('importance', ascending=False)
    return feat_imps

# %%
# Fit the train data to the model
model = DecisionTreeClassifier()
# %time model.fit(X_train, y_train)
# Out:
# CPU times: user 335 ms, sys: 14.8 ms, total: 350 ms
# Wall time: 744 ms
# DecisionTreeClassifier()

# %%
# Get an initial score
# %time score = model.score(X_train, y_train)
print("In-sample score: {:0.2%}".format(score))
feat_imps = get_feat_imp_df(model.feature_importances_, index=X_train.columns)
# Out:
# CPU times: user 19.1 ms, sys: 6.71 ms, total: 25.8 ms
# Wall time: 63.3 ms
# In-sample score: 100.00%

# %%
# Run the model
y_pred = model.predict(X_train)
y_prob = model.predict_proba(X_train)[:,1]

# %%
# Evaluate performance for the training data
metrics = evaluation.evaluate_model(y_train, y_pred, y_prob, 
                                    compare_models=['lr_simple'],
                                    store_model=True,
                                    model_name='simple', 
                                    prefix=ALGORITHM_NAME,
                                    country=COUNTRY,
                                    model=model, 
                                    features=feat_imps)
# Out:
# <style  type="text/css" >
# </style><table id="T_3971642e_ad38_11ea_b520_00155d003219" ><caption>Model Scores</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dt_simple</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row0_col0" class="data row0 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row1" class="row_heading level0 row1" >recall</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row1_col0" class="data row1 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row2" class="row_heading level0 row2" >precision</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row2_col0" class="data row2 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row3" class="row_heading level0 row3" >f1</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row3_col0" class="data row3 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row4" class="row_heading level0 row4" >cross_entropy</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row4_col0" class="data row4 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row5" class="row_heading level0 row5" >roc_auc</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row5_col0" class="data row5 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642e_ad38_11ea_b520_00155d003219level0_row6" class="row_heading level0 row6" >cohen_kappa</th>
#                         <td id="T_3971642e_ad38_11ea_b520_00155d003219row6_col0" class="data row6 col0" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# load testing data
X_test, y_test, w_test = split_features_labels_weights(mwi_test)

# %%
# Fit the test data to the model
model = DecisionTreeClassifier()
# %time model.fit(X_test, y_test)
# Out:
# CPU times: user 85.6 ms, sys: 0 ns, total: 85.6 ms
# Wall time: 196 ms
# DecisionTreeClassifier()

# %%
# Get an initial score
# %time score = model.score(X_test, y_test)
print("In-sample score: {:0.2%}".format(score))
feat_imps = get_feat_imp_df(model.feature_importances_, index=X_train.columns)
# Out:
# CPU times: user 9.62 ms, sys: 0 ns, total: 9.62 ms
# Wall time: 18.7 ms
# In-sample score: 100.00%

# %%
# Run the model
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

# %%
# Evaluate performance of the test data
metrics = evaluation.evaluate_model(y_test, y_pred, y_prob, 
                                    compare_models=['lr_simple'],
                                    store_model=True,
                                    model_name='simple', 
                                    prefix=ALGORITHM_NAME,
                                    country=COUNTRY,
                                    model=model, 
                                    features=feat_imps)
# Out:
# <style  type="text/css" >
# </style><table id="T_3971642f_ad38_11ea_b520_00155d003219" ><caption>Model Scores</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dt_simple</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row0" class="row_heading level0 row0" >accuracy</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row0_col0" class="data row0 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row1" class="row_heading level0 row1" >recall</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row1_col0" class="data row1 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row2" class="row_heading level0 row2" >precision</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row2_col0" class="data row2 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row3" class="row_heading level0 row3" >f1</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row3_col0" class="data row3 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row4" class="row_heading level0 row4" >cross_entropy</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row4_col0" class="data row4 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row5" class="row_heading level0 row5" >roc_auc</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row5_col0" class="data row5 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3971642f_ad38_11ea_b520_00155d003219level0_row6" class="row_heading level0 row6" >cohen_kappa</th>
#                         <td id="T_3971642f_ad38_11ea_b520_00155d003219row6_col0" class="data row6 col0" >1.000000</td>
#             </tr>
#     </tbody></table>
