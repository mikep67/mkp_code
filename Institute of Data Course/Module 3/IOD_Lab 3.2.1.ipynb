# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Data
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# %ls
# Out:
# Volume in drive C has no label.
#  Volume Serial Number is 36AE-B9BB
#
#  Directory of c:\Users\micha\Documents\GitHub\ds-mel-pt-24feb-projects\MichaelPresidente
#
# 03/04/2020  03:11 PM    <DIR>          .
# 03/04/2020  03:11 PM    <DIR>          ..
# 29/03/2020  07:49 PM         3,272,117 .ipynb
# 02/04/2020  09:50 PM    <DIR>          .ipynb_checkpoints
# 02/04/2020  01:59 PM    <DIR>          .vscode
# 29/03/2020  07:49 PM            73,216 24100045.xls
# 29/03/2020  07:49 PM         1,139,356 bikeshare.csv
# 29/03/2020  07:49 PM           200,088 CanadaTravel.ipynb
# 30/03/2020  10:08 AM            76,592 crimeSF_Maker.html
# 03/04/2020  12:51 PM    <DIR>          Data
# 30/03/2020  06:18 PM            51,943 IOD_Lab 2.1.3.ipynb
# 30/03/2020  06:24 PM            39,623 IOD_Lab 2.1.4.ipynb
# 29/03/2020  07:49 PM            37,440 IOD_Lab 2.1.5.ipynb
# 30/03/2020  03:10 PM            14,957 IOD_Lab 2.2.1.ipynb
# 30/03/2020  02:07 PM            83,173 IOD_Lab 2.2.4 .ipynb
# 29/03/2020  07:49 PM            90,931 IOD_Lab 3.1.1.ipynb
# 29/03/2020  08:58 PM         2,118,572 IOD_Lab 3.1.2 - answers.ipynb
# 30/03/2020  10:09 AM         7,076,218 IOD_Lab 3.1.2.ipynb
# 29/03/2020  07:49 PM           103,673 IOD_Lab 3.1.3.ipynb
# 03/04/2020  12:14 PM           374,079 IOD_Lab 3.2.1 Answers.ipynb
# 03/04/2020  03:22 PM           475,132 IOD_Lab 3.2.1.ipynb
# 29/03/2020  07:49 PM            19,247 Lab01.ipynb
# 29/03/2020  07:49 PM           314,513 Lab02.ipynb
# 29/03/2020  07:49 PM            72,401 Lab03.ipynb
# 29/03/2020  07:49 PM            33,985 Lab04_pandas.ipynb
# 29/03/2020  07:49 PM           560,916 mt_cars.ipynb
# 29/03/2020  07:49 PM             2,330 My First Project-a198d47e7e50.json
# 29/03/2020  07:49 PM                 5 readme.md
# 29/03/2020  07:49 PM                49 test
# 30/03/2020  06:17 PM            12,288 test_db.sqlite
#               25 File(s)     16,242,844 bytes
#                5 Dir(s)  91,018,469,376 bytes free

# %%
# Read Titanic Dataset
titanic = pd.read_csv(r'C:\Users\micha\Documents\GitHub\ds-mel-pt-24feb-projects\MichaelPresidente\Data\titanic_train.csv')

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female  27.0      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00     B        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00     C        C
# 890      370376   7.75   NaN        Q

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 13)

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isnull().sum()
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Filter for all female passengers
#
# SQL equivalent:
#
# ```
# SELECT *
# FROM titanic
# WHERE Sex = "female"
# ```

# %%
# select all female passengers
female_pass = titanic[(titanic['Sex'] == 'female')]
female_pass
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 8             8            9         1       3
# 9             9           10         1       2
# ..          ...          ...       ...     ...
# 880         880          881         1       2
# 882         882          883         0       3
# 885         885          886         0       3
# 887         887          888         1       1
# 888         888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  27.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833     C        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000     C        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000     B        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 13 columns]

# %%
# Try multiple conditions (AND)
titanic[(titanic['Sex'] == 'female') & (titanic['Pclass'] == 1)]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 3             3            4         1       1
# 11           11           12         1       1
# 31           31           32         1       1
# 52           52           53         1       1
# ..          ...          ...       ...     ...
# 856         856          857         1       1
# 862         862          863         1       1
# 871         871          872         1       1
# 879         879          880         1       1
# 887         887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  27.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833     C        C
# 3        0    113803   53.1000     C        S
# 11       0    113783   26.5500     C        S
# 31       0  PC 17569  146.5208     B        C
# 52       0  PC 17572   76.7292     D        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292     D        S
# 871      1     11751   52.5542     D        S
# 879      1     11767   83.1583     C        C
# 887      0    112053   30.0000     B        S
#
# [94 rows x 13 columns]

# %%
# Try multiple conditions (OR)
titanic[(titanic['Sex'] == 'female') | (titanic['Pclass'] == 1)]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 6             6            7         0       1
# 8             8            9         1       3
# ..          ...          ...       ...     ...
# 882         882          883         0       3
# 885         885          886         0       3
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  27.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833     C        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000     C        S
# 6        0             17463  51.8625     E        S
# 8        2            347742  11.1333   NaN        S
# ..     ...               ...      ...   ...      ...
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000     B        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000     C        C
#
# [436 rows x 13 columns]

# %% [markdown]
# #### What is the mean fare by Pclass?
#
# SQL equivalent:
#
# ```
# SELECT Pclass, AVG(Fare)
# FROM titanic
# GROUP BY Pclass
# ```

# %%
# Mean fare for all titanic passengers

round(titanic['Fare'].mean(), 2)
# Out:
# 32.2

# %%
# how many classes are there in Pclass?

classes = titanic['Pclass'].sort_values().unique()
print(classes)
# Out:
# [1 2 3]

# %% [markdown]
# ## Find the average fare for each Passenger Class
# ### 1) The long way - aggregate data by looping through the dataframe

# %%
# Using for loop

## Find unique values in Pclass 
classes = titanic['Pclass'].sort_values().unique()

## Save empty list to store mean fare of each class
mean_list = []
count_list = []

## loop: for each Pclass, find the mean fare and store in list
for p_class in classes:
    mean = titanic[titanic['Pclass'] == p_class]['Fare'].mean()
    mean_list.append(mean)
    
    count = len(titanic[titanic['Pclass'] == p_class]['Fare'])
    count_list.append(count)
    #print("Loop {}".format(p_class))
    #print(mean_list)
    #print(count_list)
    
print(mean_list, count_list)
# Out:
# [84.15468749999992, 20.66218315217391, 13.675550101832997] [216, 184, 491]

# %%
fare_stats_df = pd.DataFrame({'Pclass': classes, 'Count': count_list, 'Mean Fare': mean_list})
fare_stats_df
# Out:
#    Pclass  Count  Mean Fare
# 0       1    216  84.154687
# 1       2    184  20.662183
# 2       3    491  13.675550

# %% [markdown]
# ### 2 - Use panda functions to achieve the same results with less code

# %%
# Find mean fare grouped by Pclass

fare_mean_count = titanic.groupby(['Pclass'])['Fare'].agg(['count', 'mean'])
fare_mean_count
# Out:
#         count       mean
# Pclass
# 1         216  84.154687
# 2         184  20.662183
# 3         491  13.675550

# %%
print(fare_mean_count.columns)
# Out:
# Index(['count', 'mean'], dtype='object')

# %%
# Rename columns
fare_mean_count.columns = ['No. Passengers', 'Mean Fare']
fare_mean_count
# Out:
#         No. Passengers  Mean Fare
# Pclass
# 1                  216  84.154687
# 2                  184  20.662183
# 3                  491  13.675550

# %%
# Using .rename()

fare_mean_count2 =  fare_mean_count.rename(columns={'No. Passengers': 'Count',
                                                    'Fare': 'Mean'})
fare_mean_count2
# Out:
#         Count  Mean Fare
# Pclass
# 1         216  84.154687
# 2         184  20.662183
# 3         491  13.675550

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every steps

# %% [markdown]
# ### Age

# %%
# ANSWER
# From the solutions notebook
# Compared outcome with more complex functions and the results are similar
titanic['Age'].fillna(titanic.groupby(by=['Sex'])['Age'].transform("median"), inplace=True)

# %%
### Cabin
# Filter the dataframe on Cabin = nan
print(titanic[titanic['Cabin'].isna()])
# Out:
# Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 2             2            3         1       3
# 4             4            5         0       3
# 5             5            6         0       3
# 7             7            8         0       3
# ..          ...          ...       ...     ...
# 884         884          885         0       3
# 885         885          886         0       3
# 886         886          887         0       2
# 888         888          889         0       3
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 0                     Braund, Mr. Owen Harris    male  22.0      1      0
# 2                      Heikkinen, Miss. Laina  female  26.0      0      0
# 4                    Allen, Mr. William Henry    male  35.0      0      0
# 5                            Moran, Mr. James    male  29.0      0      0
# 7              Palsson, Master. Gosta Leonard    male   2.0      3      1
# ..                                        ...     ...   ...    ...    ...
# 884                    Sutehall, Mr. Henry Jr    male  25.0      0      0
# 885      Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female  27.0      1      2
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 2    STON/O2. 3101282   7.9250   NaN        S
# 4              373450   8.0500   NaN        S
# 5              330877   8.4583   NaN        Q
# 7              349909  21.0750   NaN        S
# ..                ...      ...   ...      ...
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 885            382652  29.1250   NaN        Q
# 886            211536  13.0000   NaN        S
# 888        W./C. 6607  23.4500   NaN        S
# 890            370376   7.7500   NaN        Q
#
# [687 rows x 13 columns]

# %%
# ASNWER
# How do we want to transform the data? What does the raw data look like?
titanic['Cabin'].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: Cabin, dtype: int64

# %%
# A cabin number looks like ‘C123’ and the letter refers to the deck. The decks are important because most passengers would  have been in their cabins as the Titanic collided with an iceberg late at night.
# So the numbers can be removed from the Cabin column

# Solution from solution notebook.
# Seemed to work but failed to write values to dataframe X3 tries
# titanic["Cabin"].replace(titanic["Cabin"].str[:1])
# This removed the numerics as 1st Char is an alpha
# titanic["Cabin"].str[:1]

# Update worked
titanic["Cabin"].update(titanic["Cabin"].str[:1])

# %%
# Can we determine what cabins are associated with which pclass?
titanic.groupby(by=['Pclass', 'Cabin']).agg({'Cabin': 'count'}).unstack().plot(kind='bar', figsize=(10,8));

# %% [markdown]
#  ### Cabin A, B, C & T is only available in Pclass 1.
#  #### Cabin E appears in all Passenger Classes

# %% [markdown]
# ### Embarked

# %%
# ANSWER
# Where did the passengergers board the ship?
## From the solutions notebook - didn't know about the normalize variable
titanic['Embarked'].value_counts(normalize=True)
# Out:
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: Embarked, dtype: float64

# %%
# Since most passengers boarded at S, update the two missing rows
titanic["Embarked"].fillna("S", inplace = True)

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
# ANSWER
titanic.describe(include='all')
# Out:
#         Unnamed: 0  PassengerId    Survived      Pclass  \
# count   891.000000   891.000000  891.000000  891.000000
# unique         NaN          NaN         NaN         NaN
# top            NaN          NaN         NaN         NaN
# freq           NaN          NaN         NaN         NaN
# mean    445.000000   446.000000    0.383838    2.308642
# std     257.353842   257.353842    0.486592    0.836071
# min       0.000000     1.000000    0.000000    1.000000
# 25%     222.500000   223.500000    0.000000    2.000000
# 50%     445.000000   446.000000    0.000000    3.000000
# 75%     667.500000   668.500000    1.000000    3.000000
# max     890.000000   891.000000    1.000000    3.000000
#
#                                          Name   Sex         Age       SibSp  \
# count                                     891   891  891.000000  891.000000
# unique                                    891     2         NaN         NaN
# top     Richards, Mrs. Sidney (Emily Hocking)  male         NaN         NaN
# freq                                        1   577         NaN         NaN
# mean                                      NaN   NaN   29.441268    0.523008
# std                                       NaN   NaN   13.018747    1.102743
# min                                       NaN   NaN    0.420000    0.000000
# 25%                                       NaN   NaN   22.000000    0.000000
# 50%                                       NaN   NaN   29.000000    0.000000
# 75%                                       NaN   NaN   35.000000    1.000000
# max                                       NaN   NaN   80.000000    8.000000
#
#              Parch Ticket        Fare Cabin Embarked
# count   891.000000    891  891.000000   204      891
# unique         NaN    681         NaN     8        3
# top            NaN   1601         NaN     C        S
# freq           NaN      7         NaN    59      646
# mean      0.381594    NaN   32.204208   NaN      NaN
# std       0.806057    NaN   49.693429   NaN      NaN
# min       0.000000    NaN    0.000000   NaN      NaN
# 25%       0.000000    NaN    7.910400   NaN      NaN
# 50%       0.000000    NaN   14.454200   NaN      NaN
# 75%       0.000000    NaN   31.000000   NaN      NaN
# max       6.000000    NaN  512.329200   NaN      NaN

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)
    
    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %% [markdown]
# ## Pclass
#
# Use barchart to find relationship between survived and pclass.  Note your findings.

# %%
# ANSWER
# use the bar_charts function
bar_charts(titanic,"Pclass")

# %% [markdown]
# ### Passengers from pclass 1 had a significantly higher survival rate than pclass 2 or 3

# %% [markdown]
# ## Sex
#
# Use barchart to find relationship between survived and sex.  Note your findings.

# %%
# ANSWER
bar_charts(titanic,"Sex")

# %% [markdown]
# ### Female passengers had a significantly higher survival rate than men.

# %% [markdown]
# ## Parch
#
# Parch = Number of parents of children travelling with each passenger.

# %%
# ANSWER
bar_charts(titanic,"Parch")

# %% [markdown]
# ### Children are more likely to survive if 1 or both parents where travelling with them. Children traveling with other relatives show appear to have no significant advantages to ensure survivability.  Other factors such as passenger class are far more significant in predicting survival outcomes.

# %% [markdown]
# ## SibSp

# %%
bar_charts(titanic,"Parch")

# %% [markdown]
# ### Passenger with other family members traveling with them appear to have a significant advantage that aides survivability.

# %% [markdown]
# ## Embarked

# %%
bar_charts(titanic,"Embarked")

# %% [markdown]
# ### Where passengers embarked appears to have no discernable advantage in predicting survivabilty. Survival rates appear to be proportional to where passengers embarked.
# ###  * Specifically, more passengers that embarked at South Hampton survived because most passengers embarked at this port.

# %% [markdown]
# # Feature Engineering
#
# Create some new features from existing feature.

# %% [markdown]
# ## Fare Class
#
# Create a new class based on their fare. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
# ANSWER
# Works if you add new values to DataFrame
titanic["FareClass"] = titanic["Fare"].apply(create_fare_class)

bar_charts(titanic, "FareClass")

# %% [markdown]
# ### Passengers that are in paid more for their fares have an increased survivability rate.

# %% [markdown]
# ## Age Class

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
# ANSWER
# Add AgeClass to dataframe
titanic["AgeClass"] = titanic["Age"].apply(create_age_class)

# Use bar_charts to graph
bar_charts(titanic,"AgeClass")

# %% [markdown]
# ### Passengers between the ages of 16 and 25 appear to have a significantly greater chance of surviving.

# %% [markdown]
# # Statistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
titanic.corr()
# Out:
#              Unnamed: 0  PassengerId  Survived    Pclass       Age     SibSp  \
# Unnamed: 0     1.000000     1.000000 -0.005007 -0.035144  0.035734 -0.057527
# PassengerId    1.000000     1.000000 -0.005007 -0.035144  0.035734 -0.057527
# Survived      -0.005007    -0.005007  1.000000 -0.338481 -0.073296 -0.035322
# Pclass        -0.035144    -0.035144 -0.338481  1.000000 -0.338056  0.083081
# Age            0.035734     0.035734 -0.073296 -0.338056  1.000000 -0.236376
# SibSp         -0.057527    -0.057527 -0.035322  0.083081 -0.236376  1.000000
# Parch         -0.001652    -0.001652  0.081629  0.018443 -0.176038  0.414838
# Fare           0.012658     0.012658  0.257307 -0.549500  0.094161  0.159651
# FareClass      0.003258     0.003258 -0.307600  0.719670 -0.113032 -0.380692
# AgeClass       0.026653     0.026653 -0.067911 -0.292128  0.928753 -0.232166
#
#                 Parch      Fare  FareClass  AgeClass
# Unnamed: 0  -0.001652  0.012658   0.003258  0.026653
# PassengerId -0.001652  0.012658   0.003258  0.026653
# Survived     0.081629  0.257307  -0.307600 -0.067911
# Pclass       0.018443 -0.549500   0.719670 -0.292128
# Age         -0.176038  0.094161  -0.113032  0.928753
# SibSp        0.414838  0.159651  -0.380692 -0.232166
# Parch        1.000000  0.216225  -0.387100 -0.168121
# Fare         0.216225  1.000000  -0.599129  0.075551
# FareClass   -0.387100 -0.599129   1.000000 -0.080506
# AgeClass    -0.168121  0.075551  -0.080506  1.000000

# %% [markdown]
# ## The 3 most significant factors that increase survival are:
# ### 1) Pclass - Passenger Class 1 has the highest survuval rate
# ### 2) AgeClass- Passengers between 16 and 25 are more likely to survive
# ### 3) Parch - If you were travelling with your parents, survivability increases significantly

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# Hypothesis testing is the use of statistics to determine the probability that a given hypothesis is true. The usual process of hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data, one with the passenger greater than 35 years of age and another one with the passenger younger than 35. The sample size should ideally be the same but it can be different. Lets say that the sample sizes is 100.

# %%
# ANSWER

# %% [markdown]
# ### Set alpha (Let alpha = 0.05)
#
# > Identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
# ANSWER

# %% [markdown]
# ### Calculate point estimate

# %%
a = titanic_young['Survived']
b = titanic_old['Survived']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-29264cd31654> in <module>
# ----> 1 a = titanic_young['Survived']
#       2 b = titanic_old['Survived']
#
# NameError: name 'titanic_young' is not defined

# %%
## Calculate the variance to get the standard deviation
var_a = a.var()
var_b = b.var()

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d8f593a782c8> in <module>
#       1 ## Calculate the variance to get the standard deviation
# ----> 2 var_a = a.var()
#       3 var_b = b.var()
#       4
#       5 ## Calculate the Standard Deviation
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### Calculate test statistic

# %%
## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-4cc4dca8c6cf> in <module>
#       1 ## Calculate the t-statistics
# ----> 2 t = (a.mean() - b.mean())/(s*np.sqrt(2/N))
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### Find the p-value
#
# > Compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-c8da0937c8b3> in <module>
#       1 ## Compare with the critical t-value
#       2 ## Degrees of freedom
# ----> 3 df = 2*N - 2
#       4
#       5 #p-value after comparison with the t
#
# NameError: name 'N' is not defined

# %%
print("t = " + str(t))
print("p = " + str(2*p))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-23d5a09e55a3> in <module>
# ----> 1 print("t = " + str(t))
#       2 print("p = " + str(2*p))
#
# NameError: name 't' is not defined

# %% [markdown]
# ### Interpret results
#
# > Compare the p-value to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
    else:
        print("Our test is inconclusive.")

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-20d772deacf0> in <module>
#       1 ## Cross Checking with the internal scipy function
# ----> 2 t2, p2 = stats.ttest_ind(a,b)
#       3 print("t = " + str(t2))
#       4 print("p = " + str(p2))
#       5
#
# NameError: name 'stats' is not defined

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
