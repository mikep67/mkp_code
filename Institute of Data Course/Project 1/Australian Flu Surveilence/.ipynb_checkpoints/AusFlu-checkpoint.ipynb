# %% [markdown]
# # Analysis of Influenza cases (laboratory confirmed) in Australia 2008-2017
#
# #### Data Source: NATIONAL NOTIFIABLE DISEASES SURVEILLANCE SYSTEM
# #### http://www9.health.gov.au/cda/source/pub_influ.cfm

# %%
## *** Import releevant libraries ***

import pandas as pd
import numpy as np
import math
import seaborn as sns
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
## Open the raw data file
### Source: Influenza (laboratory confirmed) Public dataset from Department of Health, Australian Government
### http://www9.health.gov.au/cda/source/pub_influ.cfm
flu_data = pd.read_csv(r"C:\Users\micha\Documents\GitHub\ds-mel-pt-24feb-projects\MichaelPresidente\Project 1\Data\Australian Influenza Public Dataset 2008 to 2017.csv")

# %%
##How does the data look?
flu_data.head(2)
# Out:
#   Week Ending State Age Group     Sex Indigenous Status Type
# 0   5/01/2018   NSW     00-04  Female     not available    B
# 1   5/01/2018   NSW     00-04  Female     not available    B

# %%
# Are there any missing values?
flu_data.isnull().sum()
# Out:
# Week Ending          0
# State                0
# Age Group            0
# Sex                  0
# Indigenous Status    0
# Type                 0
# dtype: int64

# %%
# Are the age goups OK?
flu_data.dtypes
# Out:
# Week Ending          object
# State                object
# Age Group            object
# Sex                  object
# Indigenous Status    object
# Type                 object
# dtype: object

# %%
# Check the Age Groups
flu_data.groupby('Age Group').count()
# Out:
#            Week Ending  State    Sex  Indigenous Status   Type
# Age Group
# 00-04            75022  75022  75022              75022  75022
# 15-19            42106  42106  42106              42106  42106
# 20-24            34609  34609  34609              34609  34609
# 25-29            35323  35323  35323              35323  35323
# 30-34            40189  40189  40189              40189  40189
# 35-39            41661  41661  41661              41661  41661
# 40-44            39578  39578  39578              39578  39578
# 45-49            36257  36257  36257              36257  36257
# 5-Sep            72857  72857  72857              72857  72857
# 50-54            34339  34339  34339              34339  34339
# 55-59            33367  33367  33367              33367  33367
# 60-64            30081  30081  30081              30081  30081
# 65-69            26014  26014  26014              26014  26014
# 70-74            22328  22328  22328              22328  22328
# 75-79            20962  20962  20962              20962  20962
# 80-84            19264  19264  19264              19264  19264
# 85+              29302  29302  29302              29302  29302
# Oct-14           47760  47760  47760              47760  47760
# Unknown            235    235    235                235    235

# %% [raw]
# Used Postgre queries to identify missing Age Group:
#
# 05-09
# ***********************************************************
# **  SELECT age_group FROM public.australian_influenza    **
# **          ** Where age_group = '05-09'                 **
# ** Successfully run. Total query runtime: 313 msec.      **
# ** 72857 rows affected.                                  **
# ** Corresponds flu_data: 5-Sep - 72857 rows              **
# ***********************************************************
#
# 10-14
# ***********************************************************
# **  SELECT age_group FROM public.australian_influenza    **
# **          ** Where age_group = '10-14'                 **
# ** Successfully run. Total query runtime: 375 msec.      **
# ** 47760 rows affected.                                  **
# ** Corresponds flu_data: Oct-14 - 47760 rows             **
# ***********************************************************

# %%
### update Age-Group
### 05/09/2020 - 05-09
### 14/10/2019 - 14-10

flu_data['Age Group'].replace({"5-Sep": "05-09", "Oct-14": "10-14"}, inplace=True)

# %%
# Check the Age Groups again
flu_data.groupby('Age Group').count()
# Out:
#            Week Ending  State    Sex  Indigenous Status   Type
# Age Group
# 00-04            75022  75022  75022              75022  75022
# 05-09            72857  72857  72857              72857  72857
# 10-14            47760  47760  47760              47760  47760
# 15-19            42106  42106  42106              42106  42106
# 20-24            34609  34609  34609              34609  34609
# 25-29            35323  35323  35323              35323  35323
# 30-34            40189  40189  40189              40189  40189
# 35-39            41661  41661  41661              41661  41661
# 40-44            39578  39578  39578              39578  39578
# 45-49            36257  36257  36257              36257  36257
# 50-54            34339  34339  34339              34339  34339
# 55-59            33367  33367  33367              33367  33367
# 60-64            30081  30081  30081              30081  30081
# 65-69            26014  26014  26014              26014  26014
# 70-74            22328  22328  22328              22328  22328
# 75-79            20962  20962  20962              20962  20962
# 80-84            19264  19264  19264              19264  19264
# 85+              29302  29302  29302              29302  29302
# Unknown            235    235    235                235    235

# %%
# Change the data types of each each column
flu_data['Week Ending'] = pd.to_datetime(flu_data['Week Ending'])

# %%
# Check the dtypes
flu_data.dtypes
# Out:
# Week Ending          datetime64[ns]
# State                        object
# Age Group                    object
# Sex                          object
# Indigenous Status            object
# Type                         object
# dtype: object

# %%
# check the values
flu_data.head()
# Out:
#   Week Ending State Age Group     Sex Indigenous Status           Type
# 0  2018-05-01   NSW     00-04  Female     not available              B
# 1  2018-05-01   NSW     00-04  Female     not available              B
# 2  2018-05-01   NSW     00-04    Male     not available  A(unsubtyped)
# 3  2018-05-01   NSW     20-24    Male     not available              B
# 4  2018-05-01   NSW     25-29    Male     not available  A(unsubtyped)

# %%
# Check a sample of the data:
flu_data.sample(20)
# Out:
#        Week Ending State Age Group     Sex Indigenous Status           Type
# 505421  2013-11-15   NSW     80-84  Female     not available              B
# 93394   2017-08-09   NSW     45-49    Male     not available              B
# 615395  2009-02-10    WA     20-24    Male    non-Indigenous   A(H1N1)pdm09
# 374545  2015-04-09    SA     60-64    Male     not available              B
# 415916  2015-07-24    NT     20-24    Male    non-Indigenous              B
# 680528  2008-05-23   NSW     60-64    Male     not available              B
# 91647   2017-08-09   Qld     15-19    Male    non-Indigenous  A(unsubtyped)
# 535977  2012-09-14   Qld     30-34  Female           Unknown  A(unsubtyped)
# 322831  2016-08-07   NSW     00-04    Male     not available   A(H1N1)pdm09
# 619737  2009-08-21   Qld     20-24  Female    non-Indigenous   A(H1N1)pdm09
# 236842  2017-12-05   NSW     35-39  Female     not available  A(unsubtyped)
# 84091   2017-08-09   Vic     20-24    Male     not available  A(unsubtyped)
# 44383   2017-09-22   Vic     50-54    Male     not available  A(unsubtyped)
# 319485  2016-07-22   Tas     10-14  Female     not available  A(unsubtyped)
# 149643  2017-08-18   NSW     00-04    Male     not available  A(unsubtyped)
# 431285  2015-10-04    SA     00-04  Female     not available              B
# 326265  2016-10-06   NSW     05-09    Male     not available   A(H1N1)pdm09
# 527336  2013-10-05    NT     05-09  Female    non-Indigenous  A(unsubtyped)
# 651952  2009-10-07   NSW     10-14    Male     not available  A(unsubtyped)
# 434218  2015-02-20   Qld     60-64  Female    non-Indigenous  A(unsubtyped)

# %%
# What do the statistics look like?
flu_data.describe()
# Out:
#                 Week Ending   State Age Group     Sex Indigenous Status  \
# count                681254  681254    681254  681254            681254
# unique                  523       7        19       4                 4
# top     2017-08-18 00:00:00     NSW     00-04  Female     not available
# freq                  24004  229134     75022  366829            447393
# first   2008-01-02 00:00:00     NaN       NaN     NaN               NaN
# last    2018-05-01 00:00:00     NaN       NaN     NaN               NaN
#
#                  Type
# count          681254
# unique              8
# top     A(unsubtyped)
# freq           353092
# first             NaN
# last              NaN

# %% [markdown]
# ### How to plot???

# %%
Age_Summary = flu_data.groupby("Age Group").agg({'Week Ending':['count']})

# %%
Age_Summary.head(10)
# Out:
#           Week Ending
#                 count
# Age Group
# 00-04           75022
# 05-09           72857
# 10-14           47760
# 15-19           42106
# 20-24           34609
# 25-29           35323
# 30-34           40189
# 35-39           41661
# 40-44           39578
# 45-49           36257

# %%
sns.pairplot(Age_Summary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-c8811d8c688c> in <module>
# ----> 1 sns.pairplot(Age_Summary)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2115     if grid.square_grid:
#    2116         if diag_kind == "hist":
# -> 2117             grid.map_diag(plt.hist, **diag_kws)
#    2118         elif diag_kind == "kde":
#    2119             diag_kws.setdefault("shade", True)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1467
#    1468         for var, ax in zip(self.diag_vars, self.diag_axes):
# -> 1469             hue_grouped = self.data[var].groupby(self.hue_vals)
#    1470
#    1471             plt.sca(ax)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1534         # Have the index compute an indexer or return None
#    1535         # if it cannot handle:
# -> 1536         indexer, keyarr = ax._convert_listlike_indexer(key, kind=self.name)
#    1537         # We only act on all found values:
#    1538         if indexer is not None and (indexer != -1).all():
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _convert_listlike_indexer(self, keyarr, kind)
#    2324             mask = check == -1
#    2325             if mask.any():
# -> 2326                 raise KeyError(f"{keyarr[mask]} not in index")
#    2327
#    2328         return indexer, keyarr
#
# KeyError: "['count'] not in index"
