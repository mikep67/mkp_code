# %% [markdown]
# # Practice Data Visualisation
#
#
# ## Step 1 - Import  Data
#
# ### MT Cars dataset - from GitHUB

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the data directly from a webpage (from the url)

# %%
# Load data from the above url using pandas read_csv
# Refer: pandas import csv from url
# http://pythonfiddle.com/pandas-import-csv-from-url/

# Add additional libraries
import io
import requests

# Request the data from the webpage as a string
url = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
s = requests.get(url).content

# Read the webpage into a panda dataframe
mtcars = pd.read_csv(io.StringIO(s.decode('utf-8')))

print(mtcars)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# ### Describe the data - is this recordset normalised?

# %%
# Note - () for all functions
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ## Step 2 - Use matplotlab to do some preliminary visualisation

# %%
# Define the x axis range for cylynders
# Note: This is a zero based array so add 1 more than required
x = np.arange(4,10,2)
# Check x is within the expected range
# For 3 types - 4,6 & 8 cylinders
x
# Out:
# array([4, 6, 8])

# %%
# Define the y range
# Count of models within each cyl category
y = mtcars["cyl"].value_counts()
y
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
# plot x and y
plt.plot(x,y)

# %% [markdown]
# ## Problem - need to create a bar graph
# ### This categorical data not contigious
# ### That is there is no such thing as a 4.5, 5, 6.5, 7 or 7.5 cylinder car!

# %%
# Use lists not ranges!!!
x = [np.arange(4,10,2)]
y = [mtcars["cyl"].value_counts()]

# plot x and y
plt.plot(x,y)

# %%
# Clearly wrong?
# Try this
# x,y are not lists!
x = np.arange(4,10,2)
y = mtcars["cyl"].value_counts()

# Be specific about the type of plot!
plt.bar(x,y)
plt.show()

# %%
# this is for plotting purpose
x = np.arange(4,10,2)
y = mtcars["cyl"].value_counts()
plt.bar(x,y)
plt.xlabel('No of Cylinders')
plt.ylabel('No of Cars')
plt.title('No of Cylinders for each Car')
plt.show()

# %% [markdown]
# ## Step 3 - Try a Seaborn visualisation

# %%
# import the seaborn library
import seaborn as sns

# Try the standard visulisation
sns.pairplot(mtcars)

# %%
# Now add color

sns.pairplot(mtcars, hue = "cyl")
# Out:
# C:\Users\micha\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\micha\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
