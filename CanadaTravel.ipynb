# %% [markdown]
# # MT Cars dataset - from GitHUB

# %%
# Load data from 'https://coded2.herokuapp.com/datavizpandas/london2018.csv'
# and print it
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the above url using pandas read_csv
# Refer: pandas import csv from url
# http://pythonfiddle.com/pandas-import-csv-from-url/
import io
import requests

url = 'https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv'
s = requests.get(url).content
ds = pd.read_csv(io.StringIO(s.decode('utf-8')))
#print(ds.describe())
#print(ds)

mtcars = ds

# print(weather.iloc[0:10,0:10])
# print(mtcars.head(10))

# print(mtcars)

mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %% [markdown]
# ## Let's try on a bigger recordset
#
# **let's try Canadian travel data from Statistics Canada**

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv
datafile = pd.read_csv("c:\Users\micha\Documents\Datasets\24100045-eng\24100045.csv", sep = ",")
# Out:
#   File "<ipython-input-5-29f88f1bdae4>", line 12
#     datafile = pd.read_csv("c:\Users\micha\Documents\Datasets\24100045-eng\24100045.csv", sep = ",")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 3: Saved CSV as Excel

datfile = pd.read_excel("C:\Users\micha\Documents\Datasets\CanadaTravel.xlsx")
# Out:
#   File "<ipython-input-11-7dab0e88ffe3>", line 13
#     datfile = pd.read_excel("C:\Users\micha\Documents\Datasets\CanadaTravel.xlsx")
#                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_csv( "24100045.csv")

datfile.head(10)
# Out:
#   REF_DATE                               GEO DGUID              Trip duration  \
# 0  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 1  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 2  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 3  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 4  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 5  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 6  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 7  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 8  2018-01  Total, all countries and regions   NaN                   Same-day
# 9  2018-01  Total, all countries and regions   NaN                   Same-day
#
#                                Main trip purpose       Statistics     UOM  \
# 0                       Total, all trip purposes  Number of trips  Number
# 1                 Holiday, leisure or recreation  Number of trips  Number
# 2                     Visit friends or relatives  Number of trips  Number
# 3  Personal conference, convention or trade show  Number of trips  Number
# 4                          Shopping, non-routine  Number of trips  Number
# 5                         Other personal reasons  Number of trips  Number
# 6  Business conference, convention or trade show  Number of trips  Number
# 7                                 Other business  Number of trips  Number
# 8                       Total, all trip purposes  Number of trips  Number
# 9                 Holiday, leisure or recreation  Number of trips  Number
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE  VALUE STATUS  \
# 0     223     thousands          3  v1064335310    1.1.1.1  65796      A
# 1     223     thousands          3  v1064335321    1.1.2.1  21308      A
# 2     223     thousands          3  v1064335322    1.1.3.1  26929      A
# 3     223     thousands          3  v1064335323    1.1.4.1   1065      B
# 4     223     thousands          3  v1064335324    1.1.5.1   4209      A
# 5     223     thousands          3  v1064335325    1.1.6.1   4798      A
# 6     223     thousands          3  v1064335326    1.1.7.1   2211      B
# 7     223     thousands          3  v1064335327    1.1.8.1   5277      B
# 8     223     thousands          3  v1064335314    1.2.1.1  41676      A
# 9     223     thousands          3  v1064335349    1.2.2.1  11582      A
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         0
# 1     NaN         NaN         0
# 2     NaN         NaN         0
# 3     NaN         NaN         0
# 4     NaN         NaN         0
# 5     NaN         NaN         0
# 6     NaN         NaN         0
# 7     NaN         NaN         0
# 8     NaN         NaN         0
# 9     NaN         NaN         0

# %% [markdown]
# ## Success - DGUIDs don't appear to translate well but it doesn't matter. It references internal Canadian Trips
#
# ***Next: A simple bar chart

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_csv( "24100045.csv")

datfile.plot(y = "REF_DATE", x= "GEO")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-910fe21e3d12> in <module>
#      16 datfile = pd.read_csv( "24100045.csv")
#      17
# ---> 18 datfile.plot(y = "REF_DATE", x= "GEO")
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %% [markdown]
# ### CHECK THE DATA - VALUE is numeric

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_csv( "24100045.csv")

datfile.plot(y = "GEO", x= "VALUE")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8b4ce2edc48f> in <module>
#      16 datfile = pd.read_csv( "24100045.csv")
#      17
# ---> 18 datfile.plot(y = "GEO", x= "VALUE")
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
*** No numeric? 
Try Excel file

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")
datfile.head(10)

#datfile.plot(y = "REF_DATE", x= "GEO")
# Out:
#   REF_DATE                               GEO DGUID              Trip duration  \
# 0  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 1  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 2  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 3  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 4  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 5  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 6  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 7  2018-01  Total, all countries and regions   NaN  Total, all trip durations
# 8  2018-01  Total, all countries and regions   NaN                   Same-day
# 9  2018-01  Total, all countries and regions   NaN                   Same-day
#
#                                Main trip purpose       Statistics     UOM  \
# 0                       Total, all trip purposes  Number of trips  Number
# 1                 Holiday, leisure or recreation  Number of trips  Number
# 2                     Visit friends or relatives  Number of trips  Number
# 3  Personal conference, convention or trade show  Number of trips  Number
# 4                          Shopping, non-routine  Number of trips  Number
# 5                         Other personal reasons  Number of trips  Number
# 6  Business conference, convention or trade show  Number of trips  Number
# 7                                 Other business  Number of trips  Number
# 8                       Total, all trip purposes  Number of trips  Number
# 9                 Holiday, leisure or recreation  Number of trips  Number
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE  VALUE STATUS  \
# 0     223     thousands          3  v1064335310    1.1.1.1  65796      A
# 1     223     thousands          3  v1064335321    1.1.2.1  21308      A
# 2     223     thousands          3  v1064335322    1.1.3.1  26929      A
# 3     223     thousands          3  v1064335323    1.1.4.1   1065      B
# 4     223     thousands          3  v1064335324    1.1.5.1   4209      A
# 5     223     thousands          3  v1064335325    1.1.6.1   4798      A
# 6     223     thousands          3  v1064335326    1.1.7.1   2211      B
# 7     223     thousands          3  v1064335327    1.1.8.1   5277      B
# 8     223     thousands          3  v1064335314    1.2.1.1  41676      A
# 9     223     thousands          3  v1064335349    1.2.2.1  11582      A
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         0
# 1     NaN         NaN         0
# 2     NaN         NaN         0
# 3     NaN         NaN         0
# 4     NaN         NaN         0
# 5     NaN         NaN         0
# 6     NaN         NaN         0
# 7     NaN         NaN         0
# 8     NaN         NaN         0
# 9     NaN         NaN         0

# %% [markdown]
# ### LOGICAL ERROR - x before y. No wonder this will not plot

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

datfile.plot(x = "GEO", y= "VALUE")

# %% [markdown]
# ### Success - but needs work
#
# ***Removed the GEO category "Total, all countries and regions"

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

datfile.plot(x = "GEO", y= "VALUE")

# %% [markdown]
# ## SORTED DATA IN EXCEL by country

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

datfile.plot(x = "GEO", y= "VALUE")

# %% [markdown]
# ***The issue - Countries are not aggregated as a single category**

# %% [markdown]
# ## Data is OK - seaborn should resolve the issue

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

datfile.pairplot(hue="GEO")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-c4ecd802b251> in <module>
#      17 datfile = pd.read_excel( "24100045.xlsx")
#      18
# ---> 19 datfile.pairplot(hue="GEO")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pairplot'

# %% [markdown]
# ## From Iris Example

# %%
# Load the dataset
dataset=load_CanadaTravel()
# Place in pandas dataframe
data=pd.DataFrame(dataset["data"],columns=["REF_DATE","GEO","DGUID","Trip duration","Main trip purpose","Statistics","UOM","UOM_ID","SCALAR_FACTOR","SCALAR_ID","VECTOR","COORDINATE","VALUE"])
data["Value"]=dataset["Value"]
data["Value"]=data["Value"].apply(lambda x: dataset["target_names"][x])

# use seaborn pairplot function to plot relationship between variables
sns.pairplot (data,hue="Value")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-641bfc257287> in <module>
#       1 # Load the dataset
# ----> 2 dataset=load_CanadaTravel()
#       3 # Place in pandas dataframe
#       4 data=pd.DataFrame(dataset["data"],columns=["REF_DATE","GEO","DGUID","Trip duration","Main trip purpose","Statistics","UOM","UOM_ID","SCALAR_FACTOR","SCALAR_ID","VECTOR","COORDINATE","VALUE"])
#       5 data["Value"]=dataset["Value"]
#
# NameError: name 'load_CanadaTravel' is not defined

# %% [markdown]
# ## It should be simplier than that! The file has been read into memory. Why not just create a dataframe object?
# **Answer below

# %%
trips = pd.dataframe(datfile)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-539fbdd2c196> in <module>
# ----> 1 trips = pd.dataframe(datfile)
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %% [markdown]
# trips = pd.DataFrame(datfile)

# %%
##Capitals for DataFrame
trips = pd.DataFrame(datfile)
print(trips)
# Out:
#     REF_DATE            GEO           DGUID              Trip duration  \
# 0    2018-01         Canada  2016A000011124  Total, all trip durations
# 1    2018-01         Canada  2016A000011124  Total, all trip durations
# 2    2018-01         Canada  2016A000011124  Total, all trip durations
# 3    2018-01         Canada  2016A000011124  Total, all trip durations
# 4    2018-01         Canada  2016A000011124  Total, all trip durations
# ..       ...            ...             ...                        ...
# 441  2019-07  United States             NaN                  Overnight
# 442  2019-07  United States             NaN                  Overnight
# 443  2019-07  United States             NaN                  Overnight
# 444  2019-07  United States             NaN                  Overnight
# 445  2019-07  United States             NaN                  Overnight
#
#                                  Main trip purpose       Statistics     UOM  \
# 0                         Total, all trip purposes  Number of trips  Number
# 1                   Holiday, leisure or recreation  Number of trips  Number
# 2                       Visit friends or relatives  Number of trips  Number
# 3    Personal conference, convention or trade show  Number of trips  Number
# 4                            Shopping, non-routine  Number of trips  Number
# ..                                             ...              ...     ...
# 441  Personal conference, convention or trade show  Number of trips  Number
# 442                          Shopping, non-routine  Number of trips  Number
# 443                         Other personal reasons  Number of trips  Number
# 444  Business conference, convention or trade show  Number of trips  Number
# 445                                 Other business  Number of trips  Number
#
#      UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE  VALUE STATUS  \
# 0       223     thousands          3  v1064335311    2.1.1.1  56320      A
# 1       223     thousands          3  v1064335328    2.1.2.1  16015      A
# 2       223     thousands          3  v1064335331    2.1.3.1  25072      A
# 3       223     thousands          3  v1064335334    2.1.4.1    953      B
# 4       223     thousands          3  v1064335337    2.1.5.1   3250      A
# ..      ...           ...        ...          ...        ...    ...    ...
# 441     223     thousands          3  v1064335376    3.3.4.1    134      C
# 442     223     thousands          3  v1064335381    3.3.5.1     80      D
# 443     223     thousands          3  v1064335386    3.3.6.1     90      D
# 444     223     thousands          3  v1064335391    3.3.7.1    200      C
# 445     223     thousands          3  v1064335396    3.3.8.1    159      C
#
#      SYMBOL  TERMINATED  DECIMALS
# 0       NaN         NaN         0
# 1       NaN         NaN         0
# 2       NaN         NaN         0
# 3       NaN         NaN         0
# 4       NaN         NaN         0
# ..      ...         ...       ...
# 441     NaN         NaN         0
# 442     NaN         NaN         0
# 443     NaN         NaN         0
# 444     NaN         NaN         0
# 445     NaN         NaN         0
#
# [446 rows x 17 columns]

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

trips.plot(x="Geo", y= "Value")

# %% [markdown]
# ## What do you use to Aggregate?? A Pivot Table

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

aggdata = trips.pivot_table()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-81fd303103ef> in <module>
#      20 trips = pd.DataFrame(datfile)
#      21
# ---> 22 aggdata = trips.pivot_table()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6072             dropna=dropna,
#    6073             margins_name=margins_name,
# -> 6074             observed=observed,
#    6075         )
#    6076
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      93         values = list(values)
#      94
# ---> 95     grouped = data.groupby(keys, observed=observed)
#      96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     657
#     658     if len(groupings) == 0 and len(obj):
# --> 659         raise ValueError("No group keys passed!")
#     660     elif len(groupings) == 0:
#     661         groupings.append(Grouping(Index([], dtype="int"), np.array([], dtype=np.intp)))
#
# ValueError: No group keys passed!

# %% [markdown]
# ## Which Arguments??

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

aggdata = trips.pivot_table(values="VALUE",columns="REF_DATE,GEO,VALUE")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-d2877e17f950> in <module>
#      20 trips = pd.DataFrame(datfile)
#      21
# ---> 22 aggdata = trips.pivot_table(values="VALUE",columns="REF_DATE,GEO,VALUE")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6072             dropna=dropna,
#    6073             margins_name=margins_name,
# -> 6074             observed=observed,
#    6075         )
#    6076
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      70         for i in values:
#      71             if i not in data:
# ---> 72                 raise KeyError(i)
#      73
#      74         to_filter = []
#
# KeyError: 'VALUE'

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

aggdata = trips.pivot_table(values="VALUE",columns="GEO")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-ebe5be0eb3cc> in <module>
#      20 trips = pd.DataFrame(datfile)
#      21
# ---> 22 aggdata = trips.pivot_table(values="VALUE",columns="GEO")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6072             dropna=dropna,
#    6073             margins_name=margins_name,
# -> 6074             observed=observed,
#    6075         )
#    6076
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      70         for i in values:
#      71             if i not in data:
# ---> 72                 raise KeyError(i)
#      73
#      74         to_filter = []
#
# KeyError: 'VALUE'

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

aggdata = trips.pivot_table(trips, values="GEO", columns="GEO,VALUE")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-ed1bae916b2f> in <module>
#      20 trips = pd.DataFrame(datfile)
#      21
# ---> 22 aggdata = trips.pivot_table(trips, values="GEO", columns="GEO,VALUE")
#
# TypeError: pivot_table() got multiple values for argument 'values'

# %% [markdown]
# ## MORE PRACTICE REQUIRED - Back to the PLOT

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xlsx")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

sns.pairplot(trips, hue = "GEO")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-44ca07f5c0e0> in <module>
#      20 trips = pd.DataFrame(datfile)
#      21
# ---> 22 sns.pairplot(trips, hue = "GEO")
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, height, aspect, despine, dropna, size)
#    1279
#    1280         # Label the axes
# -> 1281         self._add_axis_labels()
#    1282
#    1283         # Sort out the hue variable
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _add_axis_labels(self)
#    1516     def _add_axis_labels(self):
#    1517         """Add labels to the left and bottom Axes."""
# -> 1518         for ax, label in zip(self.axes[-1, :], self.x_vars):
#    1519             ax.set_xlabel(label)
#    1520         for ax, label in zip(self.axes[:, 0], self.y_vars):
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %% [markdown]
# ## After some further consideration ....
# ### Best to reduce the complexity of the data through munging
# ### Simplified the data by removing extra coulmns
# ### Removed the Total, all trip durations from the Destination data because it's meaningless

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xls")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

print(trips)
# Out:
#      Year Destination              Trip duration  \
# 0    2018      Canada  Total, all trip durations
# 1    2018      Canada  Total, all trip durations
# 2    2018      Canada  Total, all trip durations
# 3    2018      Canada  Total, all trip durations
# 4    2018      Canada  Total, all trip durations
# ..    ...         ...                        ...
# 441  2019    Overseas                  Overnight
# 442  2019    Overseas                  Overnight
# 443  2019    Overseas                  Overnight
# 444  2019    Overseas                  Overnight
# 445  2019    Overseas                  Overnight
#
#                                  Main trip purpose  Trips (000)
# 0                         Total, all trip purposes        56320
# 1                   Holiday, leisure or recreation        16015
# 2                       Visit friends or relatives        25072
# 3    Personal conference, convention or trade show          953
# 4                            Shopping, non-routine         3250
# ..                                             ...          ...
# 441                     Visit friends or relatives          814
# 442  Personal conference, convention or trade show           21
# 443                         Other personal reasons           73
# 444  Business conference, convention or trade show           65
# 445                                 Other business          127
#
# [446 rows x 5 columns]

# %% [markdown]
# ## 5 Columns are managable ...
#
# ### But can it be easily graphed with seaborn?

# %%
# First import libraries numpy, and pandas and matplotlib.pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from the a local csv file using pandas read_csv
# recommended additions:
import io
import requests

# Open the csv - take 7: it appears to be the path:
# solution: As suggested by Rajas

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
datfile = pd.read_excel( "24100045.xls")

## Read in the data to a DataFrame
trips = pd.DataFrame(datfile)

sns.pairplot(trips, hue = "Destination")

# %% [markdown]
# ## Compared to the Excel reference data - included in this project,  graph 2 & 3, appears correct.
#
# ### Most trips were made within Canada or to the US. This is reflected by the 2nd and 3rd graph which shows that the majority of trips in 2018 and 2019 where clearly made within Canada.
#
# ### Graph 1 over represents trips made to to the US and overseas. Canadian trips are not clearly represented.
# ### This is also apparent in Graph 4, where overseas trips are greatly over represented.
